# %%
import pandas as pd
import numpy as np
import os

# %%
results = pd.read_csv('result.txt')

# %%
traj = np.asarray([result for result in results['Para.DynPar.r2'].tolist()])
traj
# Out:
# array(['[38.85438357  0.         -1.        ]',
#        '[35.1966846  10.29246076 -1.        ]',
#        '[ 35.1966846  -10.29246076  -1.        ]',
#        '[38.0054264  -5.21254003 -1.        ]',
#        '[29.22177887 14.67347325 -1.        ]',
#        '[38.0054264   5.21254003 -1.        ]',
#        '[ 29.22177887 -14.67347325  -1.        ]',
#        '[ 32.75853014 -12.65810109  -1.        ]',
#        '[36.8871817   7.78433786 -1.        ]',
#        '[23.73135866 15.59326117 -1.        ]',
#        '[38.64528053 -2.61187538 -1.        ]',
#        '[36.8871817  -7.78433786 -1.        ]',
#        '[32.75853014 12.65810109 -1.        ]',
#        '[38.64528053  2.61187538 -1.        ]',
#        '[ 23.73135866 -15.59326117  -1.        ]',
#        '[ 26.8175956  -15.37411222  -1.        ]',
#        '[38.38122378  3.91454978 -1.        ]',
#        '[31.16177304 13.73324326 -1.        ]',
#        '[37.51049303 -6.5035811  -1.        ]',
#        '[38.80183464 -1.30656561 -1.        ]',
#        '[19.49701753 14.56694501 -1.        ]',
#        '[36.12181342  9.04980428 -1.        ]',
#        '[ 34.08706678 -11.50113846  -1.        ]',
#        '[ 31.16177304 -13.73324326  -1.        ]',
#        '[37.51049303  6.5035811  -1.        ]',
#        '[26.8175956  15.37411222 -1.        ]',
#        '[38.38122378 -3.91454978 -1.        ]',
#        '[36.12181341 -9.04980428 -1.        ]',
#        '[34.08706678 11.50113846 -1.        ]',
#        '[38.80183464  1.30656561 -1.        ]',
#        '[ 19.49701753 -14.56694501  -1.        ]',
#        '[ 21.8060856  -15.33684146  -1.        ]',
#        '[38.73673329  1.9595074  -1.        ]',
#        '[33.45285963 12.08749714 -1.        ]',
#        '[36.52324421 -8.41934685 -1.        ]',
#        '[38.52697731 -3.26366251 -1.        ]',
#        '[25.37993416 15.56988503 -1.        ]',
#        '[37.2157421  7.145541  -1.       ]',
#        '[ 31.99756609 -13.20837909  -1.        ]',
#        '[ 34.66683458 -10.90200351  -1.        ]',
#        '[35.68058305  9.67445247 -1.        ]',
#        '[16.63165538 12.59564867 -1.        ]',
#        '[38.84077982 -0.65340533 -1.        ]',
#        '[37.77339818 -5.85926227 -1.        ]',
#        '[30.24074684 14.22495251 -1.        ]',
#        '[38.20768864  4.56427535 -1.        ]',
#        '[ 28.08816512 -15.06383855  -1.        ]',
#        '[ 25.37993417 -15.56988503  -1.        ]',
#        '[38.52697731  3.26366251 -1.        ]',
#        '[31.99756609 13.20837909 -1.        ]',
#        '[37.2157421 -7.145541  -1.       ]',
#        '[38.73673329 -1.9595074  -1.        ]',
#        '[21.8060856  15.33684146 -1.        ]',
#        '[36.52324421  8.41934685 -1.        ]',
#        '[ 33.45285963 -12.08749714  -1.        ]',
#        '[ 30.24074684 -14.22495251  -1.        ]',
#        '[37.77339818  5.85926227 -1.        ]',
#        '[28.08816512 15.06383855 -1.        ]',
#        '[38.20768864 -4.56427536 -1.        ]',
#        '[35.68058305 -9.67445247 -1.        ]',
#        '[34.66683458 10.90200351 -1.        ]',
#        '[38.84077982  0.65340533 -1.        ]',
#        '[ 16.63165538 -12.59564867  -1.        ]',
#        '[ 18.14686212 -13.81952475  -1.        ]',
#        '[38.8245332  0.9799719 -1.       ]',
#        '[34.38340896 11.20295657 -1.        ]',
#        '[35.90643853 -9.3628388  -1.        ]',
#        '[38.29802492 -4.23949966 -1.        ]',
#        '[27.4716815  15.23076186 -1.        ]',
#        '[37.64583292  6.18160569 -1.        ]',
#        '[ 30.71266466 -13.9837552   -1.        ]',
#        '[ 33.77703301 -11.79605171  -1.        ]',
#        '[36.32732526  8.7351755  -1.        ]',
#        '[20.70844822 15.04044511 -1.        ]',
#        '[38.77252286 -1.63313698 -1.        ]',
#        '[37.36716392 -6.8249625  -1.        ]',
#        '[31.58958834 13.47438343 -1.        ]',
#        '[38.45757867  3.58925349 -1.        ]',
#        '[ 26.12200494 -15.48922898  -1.        ]',
#        '[ 28.67053411 -14.87706932  -1.        ]',
#        '[38.11016184  4.88862304 -1.        ]',
#        '[29.74448078 14.4553258  -1.        ]',
#        '[37.89316151 -5.53610988 -1.        ]',
#        '[38.85058147 -0.32668828 -1.        ]',
#        '[14.97939205 10.32930214 -1.        ]',
#        '[35.4441863   9.98436527 -1.        ]',
#        '[ 34.93768643 -10.59831943  -1.        ]',
#        '[ 32.38688712 -12.9360188   -1.        ]',
#        '[37.05566777  7.46536399 -1.        ]',
#        '[24.58547345 15.60818216 -1.        ]',
#        '[38.58944353 -2.93779385 -1.        ]',
#        '[36.70962051 -8.10234692 -1.        ]',
#        '[33.11365329 12.37495978 -1.        ]',
#        '[38.69425578  2.28582137 -1.        ]',
#        '[ 22.80870633 -15.51008861  -1.        ]',
#        '[ 20.70844822 -15.04044511  -1.        ]',
#        '[38.77252286  1.63313698 -1.        ]',
#        '[33.77703301 11.79605171 -1.        ]',
#        '[36.32732526 -8.7351755  -1.        ]',
#        '[38.45757867 -3.58925349 -1.        ]'], dtype='<U40')

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots

traj = np.asarray(results['Para.DynPar.r2'].tolist())

# Create the figure object
fig = make_subplots(rows=1, cols=1)
fig.layout.title = "Probability"
fig.layout.yaxis.title = 'Y Position'

fig.add_trace(
    go.Scatter(
        x=traj[:,0],
        y=traj[:,1],
        mode = 'markers'
    ),
    row = 1,
    col = 1,
)
fig.get_subplot(1, 1).xaxis.title = "X Position"

fig.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 13
#       8 fig.layout.title = "Probability"
#       9 fig.layout.yaxis.title = 'Y Position'
#      11 fig.add_trace(
#      12     go.Scatter(
# ---> 13         x=traj[:,0],
#      14         y=traj[:,1],
#      15         mode = 'markers'
#      16     ),
#      17     row = 1,
#      18     col = 1,
#      19 )
#      20 fig.get_subplot(1, 1).xaxis.title = "X Position"
#      22 fig.show()
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
